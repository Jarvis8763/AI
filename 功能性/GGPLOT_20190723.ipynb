# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')

N=50
x=np.random.rand(N)
z=np.random.rand(N)
colors=np.random.rand(N)
area=(30*np.random.rand(N))**2

plt.scatter(x,z,area,c=colors,alpha=0.5)
